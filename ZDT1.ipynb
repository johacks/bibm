# %%
import ZDT
import Metrics

zdt1 = ZDT.ZDT1()
frontier = zdt1.get_global_pareto_front_points()
metrics=[Metrics.GenerationalDistance(frontier=frontier),
         Metrics.Spacing()]
zdt1.test(metrics=metrics, max_generation=20)
